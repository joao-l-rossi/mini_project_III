# %%
import pandas as pd
import sqlite3
from sqlite3 import Error 
from sklearn.datasets import load_wine
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

# %% [markdown]
# # Getting the data from database and merging population from other data source

# %%
def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

connection = create_connection("twm_banking.sqlite")
customers = pd.read_sql_query("SELECT * FROM customers", connection)
# Out:
# Connection to SQLite DB successful
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\bootcamp_as1\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# OperationalError: no such table: customers
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27616/3877508543.py in <module>
#      10
#      11 connection = create_connection("twm_banking.sqlite")
# ---> 12 customers = pd.read_sql_query("SELECT * FROM customers", connection)
#
# ~\anaconda3\envs\bootcamp_as1\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     434     """
#     435     pandas_sql = pandasSQL_builder(con)
# --> 436     return pandas_sql.read_query(
#     437         sql,
#     438         index_col=index_col,
#
# ~\anaconda3\envs\bootcamp_as1\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2114
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#
# ~\anaconda3\envs\bootcamp_as1\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT * FROM customers': no such table: customers

# %%
customers.head()
# Out:
#    index  cust_id  income  age  years_with_bank  nbr_children gender  \
# 0      0  1362691   26150   46                5             1     M
# 1      1  1362487    6605   71                1             0     M
# 2      2  1363160   18548   38                8             0     F
# 3      3  1362752   47668   54                3             0     F
# 4      4  1362548   44554   59                9             2     F
#
#    marital_status name_prefix first_name last_name  street_nbr street_name  \
# 0               2                 Donald     Marek        8298      Second
# 1               2               ChingDyi  Moussavi       10603    Daffodil
# 2               1                   Rosa  Johnston        8817    Figueroa
# 3               1                   Lisa    Martin         676      Humble
# 4               4                Barbara  O'Malley        6578           C
#
#    postal_code      city_name state_code    full_address          full_name
# 0        89194      Las Vegas         NV     8298 Second       Donald Marek
# 1        90159    Los Angeles         CA  10603 Daffodil  ChingDyi Moussavi
# 2        90024    Los Angeles         CA   8817 Figueroa      Rosa Johnston
# 3        90172    Los Angeles         CA      676 Humble        Lisa Martin
# 4        10138  New York City         NY          6578 C   Barbara O'Malley

# %%
customers["index_city"] = customers["city_name"]
cities = pd.read_csv("cities.csv", sep = ",")
cities.head()
# Out:
#    Unnamed: 0    index_city  Population
# 0         309        Pelham       22885
# 1         310       Thorsby        2044
# 2         311     Uniontown        2415
# 3         312    Farmington        6701
# 4         313  Little Flock        2748

# %% [markdown]
# ### [source: opendatasoft](https://public.opendatasoft.com/explore/dataset/geonames-all-cities-with-a-population-1000/table/?disjunctive.cou_name_en&sort=name&refine.timezone=America)

# %%
custumers_pop = customers.merge(cities, how = 'left')
custumers_pop.shape
# Out:
# (2183, 21)

# %% [markdown]
# # Exploratory of the numerical features

# %%
custumers_num = custumers_pop[["income", "age", "years_with_bank", "nbr_children", "Population"]]

# %%
custumers_num.describe()
# Out:
#               income          age  years_with_bank  nbr_children    Population
# count    2183.000000  2183.000000      2183.000000   2183.000000  2.183000e+03
# mean    21474.969308    41.491984         3.989006      0.671553  7.778788e+05
# std     21339.820715    18.647529         2.634271      1.111044  1.846335e+06
# min         0.000000    13.000000         0.000000      0.000000  1.280000e+02
# 25%      6493.000000    28.000000         2.000000      0.000000  2.311000e+03
# 50%     16422.000000    41.000000         4.000000      0.000000  9.054000e+03
# 75%     29916.500000    55.000000         6.000000      1.000000  5.200520e+05
# max    144157.000000    89.000000         9.000000      5.000000  8.175133e+06

# %%
sns.set_theme(style="ticks")
sns.pairplot(custumers_num)

# %%
corr = custumers_num.corr()
mask = np.zeros_like(corr, dtype= bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(
    corr,          # The data to plot
    mask=mask,     # Mask some cells
    annot=True,    # Should the values be plotted in the cells?
    vmax= 1,       # The maximum value of the legend. All higher vals will be same color
    vmin= -1,      # The minimum value of the legend. All lower vals will be same color
    center=0,      # The center value of the legend. With divergent cmap, where white is
    square=True,   # Force cells to be square
    linewidths=.5, # Width of lines that divide cells
    cbar_kws={"shrink": .5}  # Extra kwargs for the legend; in this case, shrink by 50%
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scaling and K-means

# %%
scaler = MinMaxScaler(feature_range=(0, 5))
#scaler = StandardScaler()
data_std = scaler.fit_transform(custumers_num)

# %%
def plot_distortion(X,max_clusters = 10):
    distortions = []
    for i in range(1, max_clusters +1):
        km = KMeans(n_clusters=i,
                    init='k-means++',
                    n_init=10,
                    random_state=0)
        km.fit(X)
        distortions.append(km.inertia_)

    plt.plot(range(1,max_clusters +1), distortions, marker='o', color='black')
    plt.title('Elbow plot - demographics')
    plt.xlabel('Number of clusters')
    plt.ylabel('Distortion')
    plt.show()

# %%
plot_distortion(data_std) # No Elbow! I will call it 4

# %%
km = KMeans(n_clusters=4, #number of clusters
           n_init = 10, #how many initial runs
           random_state = 0)

# %%
y_km = km.fit_predict(data_std)

# %%
groups = pd.DataFrame(y_km)+1
groups.rename(columns = {0:"Group"}, inplace = True)
df_groups = pd.DataFrame(data_std,columns = custumers_num.columns)
df_groups.head()
# Out:
#      income       age  years_with_bank  nbr_children  Population
# 0  0.906997  2.171053         2.777778           1.0    0.381418
# 1  0.906997  2.171053         2.777778           1.0    0.008109
# 2  0.229091  3.815789         0.555556           0.0    2.429206
# 3  0.643326  1.644737         4.444444           0.0    2.429206
# 4  1.653336  2.697368         1.666667           0.0    2.429206

# %%
df_groups = pd.concat([df_groups,groups], axis = 1)
df_groups.shape
# Out:
# (2183, 6)

# %% [markdown]
# # Radar Plot

# %%
group_mean_df = df_groups.groupby("Group").mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fb46520769ce> in <module>
# ----> 1 group_mean_df = df_groups.groupby("Group").mean()
#
# NameError: name 'df_groups' is not defined

# %%
import plotly.graph_objects as go
import plotly.offline as pyo

# %%
categories = ['Income', 'Age', 'Years with bank', 'Number of children', 'City Population']
categories = [*categories, categories[0]]

# %%
Group_1 = list(group_mean_df.iloc[0,:])
Group_2 = list(group_mean_df.iloc[1,:])
Group_3 = list(group_mean_df.iloc[2,:])
Group_4 = list(group_mean_df.iloc[3,:])
Group_1 = [*Group_1, Group_1[0]]
Group_2 = [*Group_2, Group_2[0]]
Group_3 = [*Group_3, Group_3[0]]
Group_4 = [*Group_4, Group_4[0]]

# %%
fig = go.Figure(
    data=[
        go.Scatterpolar(r=Group_1, theta=categories, fill='none', name='Group 1'),
        go.Scatterpolar(r=Group_2, theta=categories, fill='none', name='Group 2'),
        go.Scatterpolar(r=Group_3, theta=categories, fill='none', name='Group 3'),
        go.Scatterpolar(r=Group_4, theta=categories, fill='none', name='Group 4')
    ],
    layout=go.Layout(
        title=go.layout.Title(text='Customer Groups'),
        polar={'radialaxis': {'visible': True}},
        showlegend=True
    )
)

pyo.plot(fig)
# Out:
# 'temp-plot.html'

# %% [markdown]
# # PCA

# %%
n_components = 2
pca = PCA(n_components = n_components)
components = pca.fit_transform(data_std)

# %%
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)" for i, var in enumerate(pca.explained_variance_ratio_ *100)
}
labels
# Out:
# {'0': 'PC 1 (33.5%)', '1': 'PC 2 (22.5%)'}

# %%
df_PCA = pd.DataFrame(components, columns=[f'PC-{i+1}' for i in range(n_components)], index=custumers_pop.index)

# %%
 def plot_clusters(X,y_res, plt_cluster_centers = False):
    X_centroids = []
    Y_centroids = []

    for cluster in set(y_res):
        x = X[y_res == cluster]["PC-1"]
        y = X[y_res == cluster]["PC-2"]
        X_centroids.append(np.mean(x))
        Y_centroids.append(np.mean(y))

        plt.scatter(x,
                    y,
                    s=50,
                    marker='s',
                    label=f'cluster {cluster}')

    if plt_cluster_centers:
        plt.scatter(X_centroids,
                    Y_centroids,
                    marker='*',
                    c='red',
                    s=250,
                    label='centroids')
    plt.title('Principal components - demographics')
    plt.xlabel('PC-2')
    plt.ylabel('PC-1')
    plt.legend()
    plt.grid()
    plt.show()

# %%
plot_clusters(df_PCA, y_km)

# %% [markdown]
# ### I did PCA here because the exercise asked for, but as you can see one group (red) is mixed with others, probably because the distinction is in another Principal component.
# ### It seems to be that using linear discriminant analysis would be better here.
